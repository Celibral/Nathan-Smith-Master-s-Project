# %%
import pandas as pd
import math
import numpy as np
from matplotlib import pyplot as plt
from numpy import mean

# %%
df = pd.read_csv('C:/Users/no1ca/OneDrive/Documents/Masters/Final Masters Model/Iteration_1/PE_data.csv', index_col=[0])

# %%
df.head()
# Out:
#    Starting_Mass  Height  Parity  Multiple_Fetuses  HT_History  \
# 0           50.9     156       0             False       False
# 1           79.6       0       0             False       False
# 2            0.0       0       0             False       False
# 3           70.0     173       4             False       False
# 4           50.0       0       0             False       False
#
#    Previous_Miscarriage  Previous_Stillbirth  Diabetic  Diabetes_Fhistory  \
# 0                 False                False     False              False
# 1                 False                False     False              False
# 2                 False                False     False              False
# 3                  True                False     False              False
# 4                 False                False     False              False
#
#    Age  ...  Starting_SBP  Starting_DBP  SBP_1  DBP_1  SBP_2  DBP_2  SBP_3  \
# ...

# %%
# make a list of the variables that contain missing values
vars_with_na = ['Height','Starting_Mass','Mass_1','Mass_2','Mass_3','Mass_4','Starting_SBP','SBP_1','SBP_4','Starting_DBP','DBP_1','DBP_4','Starting_Week', 'Week_1', 'Week_2', 'Week_3','Week_4']

# %%
# plot

(df[vars_with_na] == 0).mean().sort_values(
    ascending=False).plot.bar(figsize=(10, 4))
plt.ylabel('Percentage of missing data')
plt.subplots_adjust(bottom=0.35)
plt.savefig('it1_mis_perc.png')

plt.show()
